# %%
import tensorflow as tf 
import tensorflow.keras as keras
# Out:
# 2023-03-29 11:08:49.244385: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-03-29 11:08:49.244399: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = [28,28]),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(300, activation = 'elu', kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(100, activation = 'elu', kernel_initializer="he_normal"),
    keras.layers.BatchNormalization()
])
model.compile()
# Out:
# 2023-03-29 11:08:49.973427: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-03-29 11:08:49.973567: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-03-29 11:08:49.973573: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-03-29 11:08:49.973584: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (pedro): /proc/driver/nvidia/version does not exist
# 2023-03-29 11:08:49.973725: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 784)               3136
# _________________________________________________________________
# dense (Dense)                (None, 300)               235500
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 300)               1200
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               30100
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 100)               400
# ...
# Total params: 270,336
# Trainable params: 267,968
# Non-trainable params: 2,368
# ...

# %%
[(var.name, var.trainable) for var in model.layers[1].variables]
# Out:
# [('batch_normalization/gamma:0', True),
#  ('batch_normalization/beta:0', True),
#  ('batch_normalization/moving_mean:0', False),
#  ('batch_normalization/moving_variance:0', False)]

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = [28,28]),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(300, kernel_initializer="he_normal",use_bias= False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("elu"),
    keras.layers.Dense(100, kernel_initializer="he_normal",use_bias= False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("elu"),
    keras.layers.Dense(10, activation ='softmax'),

])
model.compile(optimizer='sgd',loss='sparse_categorical_crossentropy', metrics='accuracy')

# %%
(X_train_full, y_train_full), (X_test, y_test)  = keras.datasets.mnist.load_data()
X_train, X_valid = X_train_full[5000:] / 255, X_train_full[:5000] / 255
y_train, y_valid = y_train_full[5000:], y_train_full[:5000]
X_test = X_test / 255

# %%
model.fit(X_train,y_train, validation_data=(X_valid, y_valid),epochs=100, callbacks =[keras.callbacks.EarlyStopping(patience = 10)])
# Out:
# 2023-03-29 11:08:50.471121: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2023-03-29 11:08:50.471334: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2688000000 Hz
# Epoch 1/100
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.6493 - accuracy: 0.8057 - val_loss: 0.2701 - val_accuracy: 0.9240
# Epoch 2/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2958 - accuracy: 0.9149 - val_loss: 0.2209 - val_accuracy: 0.9384
# Epoch 3/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2414 - accuracy: 0.9295 - val_loss: 0.1982 - val_accuracy: 0.9442
# Epoch 4/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2122 - accuracy: 0.9395 - val_loss: 0.1764 - val_accuracy: 0.9494
# Epoch 5/100
# ...

# %% [markdown]
# Momentum

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = [28,28]),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(300, kernel_initializer="he_normal",use_bias= False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("elu"),
    keras.layers.Dense(100, kernel_initializer="he_normal",use_bias= False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("elu"),
    keras.layers.Dense(10, activation ='softmax'),

])
model.compile(optimizer=keras.optimizers.SGD(lr=0.001,momentum=0.9),loss='sparse_categorical_crossentropy', metrics='accuracy')
model.fit(X_train,y_train, validation_data=(X_valid, y_valid),epochs=100, callbacks =[keras.callbacks.EarlyStopping(patience = 10)])
# Out:
# Epoch 1/100
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.6700 - accuracy: 0.7960 - val_loss: 0.2626 - val_accuracy: 0.9256
# Epoch 2/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2933 - accuracy: 0.9161 - val_loss: 0.2170 - val_accuracy: 0.9370
# Epoch 3/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2386 - accuracy: 0.9309 - val_loss: 0.1903 - val_accuracy: 0.9444
# Epoch 4/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2060 - accuracy: 0.9395 - val_loss: 0.1733 - val_accuracy: 0.9482
# Epoch 5/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.1802 - accuracy: 0.9490 - val_loss: 0.1573 - val_accuracy: 0.9554
# Epoch 6/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.1569 - accuracy: 0.9543 - val_loss: 0.1496 - val_accuracy: 0.9558
# Epoch 7/100
# ...

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = [28,28]),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(300, kernel_initializer="he_normal",use_bias= False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("elu"),
    keras.layers.Dense(100, kernel_initializer="he_normal",use_bias= False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("elu"),
    keras.layers.Dense(10, activation ='softmax'),

])
model.compile(optimizer=keras.optimizers.SGD(lr=0.001,momentum=0.9, nesterov= True),loss='sparse_categorical_crossentropy', metrics='accuracy')
model.fit(X_train,y_train, validation_data=(X_valid, y_valid),epochs=100, callbacks =[keras.callbacks.EarlyStopping(patience = 10)])
# Out:
# Epoch 1/100
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.6768 - accuracy: 0.7957 - val_loss: 0.2620 - val_accuracy: 0.9240
# Epoch 2/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2832 - accuracy: 0.9185 - val_loss: 0.2180 - val_accuracy: 0.9370
# Epoch 3/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2350 - accuracy: 0.9321 - val_loss: 0.1944 - val_accuracy: 0.9450
# Epoch 4/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2087 - accuracy: 0.9382 - val_loss: 0.1783 - val_accuracy: 0.9492
# Epoch 5/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.1814 - accuracy: 0.9463 - val_loss: 0.1639 - val_accuracy: 0.9522
# Epoch 6/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.1600 - accuracy: 0.9535 - val_loss: 0.1555 - val_accuracy: 0.9538
# Epoch 7/100
# ...

# %% [markdown]
# RMSprop

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = [28,28]),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(300, kernel_initializer="he_normal",use_bias= False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("elu"),
    keras.layers.Dense(100, kernel_initializer="he_normal",use_bias= False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("elu"),
    keras.layers.Dense(10, activation ='softmax'),

])
model.compile(optimizer=keras.optimizers.RMSprop(lr=0.001,rho=0.9),loss='sparse_categorical_crossentropy', metrics='accuracy')
model.fit(X_train,y_train, validation_data=(X_valid, y_valid),epochs=100, callbacks =[keras.callbacks.EarlyStopping(patience = 10)])
# Out:
# Epoch 1/100
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3773 - accuracy: 0.8882 - val_loss: 0.1494 - val_accuracy: 0.9552
# Epoch 2/100
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1575 - accuracy: 0.9525 - val_loss: 0.1231 - val_accuracy: 0.9648
# Epoch 3/100
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1144 - accuracy: 0.9645 - val_loss: 0.1097 - val_accuracy: 0.9694
# Epoch 4/100
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0953 - accuracy: 0.9709 - val_loss: 0.0987 - val_accuracy: 0.9738
# Epoch 5/100
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0792 - accuracy: 0.9751 - val_loss: 0.0926 - val_accuracy: 0.9732
# Epoch 6/100
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0667 - accuracy: 0.9797 - val_loss: 0.0913 - val_accuracy: 0.9740
# Epoch 7/100
# ...

# %% [markdown]
# Adam

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = [28,28]),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(300, kernel_initializer="he_normal",use_bias= False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("elu"),
    keras.layers.Dense(100, kernel_initializer="he_normal",use_bias= False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("elu"),
    keras.layers.Dense(10, activation ='softmax'),

])
model.compile(optimizer=keras.optimizers.Adam(lr=0.001,beta_1=0.9, beta_2=0.999),loss='sparse_categorical_crossentropy', metrics='accuracy')
model.fit(X_train,y_train, validation_data=(X_valid, y_valid),epochs=100, callbacks =[keras.callbacks.EarlyStopping(patience = 10)])
# Out:
# Epoch 1/100
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4019 - accuracy: 0.8767 - val_loss: 0.1626 - val_accuracy: 0.9546
# Epoch 2/100
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.1509 - accuracy: 0.9536 - val_loss: 0.1428 - val_accuracy: 0.9608
# Epoch 3/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.1109 - accuracy: 0.9658 - val_loss: 0.1009 - val_accuracy: 0.9694
# Epoch 4/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0889 - accuracy: 0.9726 - val_loss: 0.1045 - val_accuracy: 0.9698
# Epoch 5/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0692 - accuracy: 0.9780 - val_loss: 0.1087 - val_accuracy: 0.9722
# Epoch 6/100
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0627 - accuracy: 0.9799 - val_loss: 0.1194 - val_accuracy: 0.9700
# Epoch 7/100
# ...

# %% [markdown]
# learning rate scheduling

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = [28,28]),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(300, kernel_initializer="he_normal",use_bias= False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("elu"),
    keras.layers.Dense(100, kernel_initializer="he_normal",use_bias= False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("elu"),
    keras.layers.Dense(10, activation ='softmax'),

])
model.compile(optimizer=keras.optimizers.SGD(lr=0.01, decay=1e-4),loss='sparse_categorical_crossentropy', metrics='accuracy')
model.fit(X_train,y_train, validation_data=(X_valid, y_valid),epochs=100, callbacks =[keras.callbacks.EarlyStopping(patience = 10)])
# Out:
# Epoch 1/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.6585 - accuracy: 0.8028 - val_loss: 0.2703 - val_accuracy: 0.9276
# Epoch 2/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2938 - accuracy: 0.9135 - val_loss: 0.2257 - val_accuracy: 0.9354
# Epoch 3/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2487 - accuracy: 0.9288 - val_loss: 0.2056 - val_accuracy: 0.9432
# Epoch 4/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2249 - accuracy: 0.9365 - val_loss: 0.1921 - val_accuracy: 0.9468
# Epoch 5/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2048 - accuracy: 0.9405 - val_loss: 0.1836 - val_accuracy: 0.9484
# Epoch 6/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.1855 - accuracy: 0.9456 - val_loss: 0.1769 - val_accuracy: 0.9496
# Epoch 7/100
# ...

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1**(epoch/s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(lr0=0.01, s=20)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = [28,28]),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(300, kernel_initializer="he_normal",use_bias= False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("elu"),
    keras.layers.Dense(100, kernel_initializer="he_normal",use_bias= False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("elu"),
    keras.layers.Dense(10, activation ='softmax'),

])
lr_scheduler = keras.callbacks.LearningRateScheduler(exponential_decay_fn)
model.compile(optimizer=keras.optimizers.SGD(lr=0.01, decay=1e-4),loss='sparse_categorical_crossentropy', metrics='accuracy')
model.fit(X_train,y_train, validation_data=(X_valid, y_valid),epochs=100, callbacks =[keras.callbacks.EarlyStopping(patience = 10), lr_scheduler])
# Out:
# Epoch 1/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.6740 - accuracy: 0.7960 - val_loss: 0.2627 - val_accuracy: 0.9256
# Epoch 2/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2996 - accuracy: 0.9115 - val_loss: 0.2290 - val_accuracy: 0.9364
# Epoch 3/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2575 - accuracy: 0.9265 - val_loss: 0.2095 - val_accuracy: 0.9402
# Epoch 4/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2305 - accuracy: 0.9345 - val_loss: 0.1974 - val_accuracy: 0.9440
# Epoch 5/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2159 - accuracy: 0.9382 - val_loss: 0.1883 - val_accuracy: 0.9470
# Epoch 6/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2020 - accuracy: 0.9425 - val_loss: 0.1839 - val_accuracy: 0.9478
# Epoch 7/100
# ...

# %% [markdown]
# piecewise_constant

# %%
def piece_wise_constant_fn(epoch):
    if epoch < 5:
        return 0.01
    elif epoch < 15:
        return 0.005
    else: 
        return 0.001

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = [28,28]),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(300, kernel_initializer="he_normal",use_bias= False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("elu"),
    keras.layers.Dense(100, kernel_initializer="he_normal",use_bias= False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("elu"),
    keras.layers.Dense(10, activation ='softmax'),

])
lr_scheduler = keras.callbacks.ReduceLROnPlateau(patience=5,factor = 0.5)
model.compile(optimizer=keras.optimizers.SGD(lr=0.01, decay=1e-4),loss='sparse_categorical_crossentropy', metrics='accuracy')
model.fit(X_train,y_train, validation_data=(X_valid, y_valid),epochs=100, callbacks =[keras.callbacks.EarlyStopping(patience = 10), lr_scheduler])
# Out:
# Epoch 1/100
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.6710 - accuracy: 0.8022 - val_loss: 0.2736 - val_accuracy: 0.9196
# Epoch 2/100
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.3067 - accuracy: 0.9096 - val_loss: 0.2301 - val_accuracy: 0.9344
# Epoch 3/100
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.2552 - accuracy: 0.9275 - val_loss: 0.2108 - val_accuracy: 0.9368
# Epoch 4/100
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.2277 - accuracy: 0.9350 - val_loss: 0.1914 - val_accuracy: 0.9438
# Epoch 5/100
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.2093 - accuracy: 0.9394 - val_loss: 0.1819 - val_accuracy: 0.9466
# Epoch 6/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.1899 - accuracy: 0.9450 - val_loss: 0.1729 - val_accuracy: 0.9486
# Epoch 7/100
# ...

# %% [markdown]
# regularization

# %%
from functools import partial
RegularizedDense = partial(keras.layers.Dense, activation='elu', kernel_initializer = "he_normal",kernel_regularizer = keras.regularizers.l2(0.01))

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = [28,28]),
    RegularizedDense(300),
    RegularizedDense(100),
    RegularizedDense(10, activation='softmax',kernel_initializer="glorot_uniform")
    
])
lr_scheduler = keras.callbacks.ReduceLROnPlateau(patience=5,factor = 0.5)
model.compile(optimizer=keras.optimizers.SGD(lr=0.01, decay=1e-4),loss='sparse_categorical_crossentropy', metrics='accuracy')
model.fit(X_train,y_train, validation_data=(X_valid, y_valid),epochs=100, callbacks =[keras.callbacks.EarlyStopping(patience = 10), lr_scheduler])
# Out:
# Epoch 1/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 7.9020 - accuracy: 0.7724 - val_loss: 4.9285 - val_accuracy: 0.9038
# Epoch 2/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 4.4238 - accuracy: 0.8971 - val_loss: 3.1596 - val_accuracy: 0.9078
# Epoch 3/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 2.9172 - accuracy: 0.8983 - val_loss: 2.2407 - val_accuracy: 0.9086
# Epoch 4/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 2.1085 - accuracy: 0.9057 - val_loss: 1.7237 - val_accuracy: 0.9108
# Epoch 5/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 1.6595 - accuracy: 0.9028 - val_loss: 1.4140 - val_accuracy: 0.9092
# Epoch 6/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 1.3763 - accuracy: 0.9043 - val_loss: 1.2207 - val_accuracy: 0.9118
# Epoch 7/100
# ...

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = [28,28]),
    keras.layers.Dropout(rate=0.2),
    keras.layers.Dense(300, kernel_initializer="he_normal",use_bias= False),
    keras.layers.Dropout(rate=0.2),
    keras.layers.Activation("elu"),
    keras.layers.Dense(100, kernel_initializer="he_normal",use_bias= False),
    keras.layers.Dropout(rate=0.2),
    keras.layers.Activation("elu"),
    keras.layers.Dense(10, activation ='softmax'),

])

model.compile(optimizer=keras.optimizers.SGD(lr=0.01),loss='sparse_categorical_crossentropy', metrics='accuracy')
model.fit(X_train,y_train, validation_data=(X_valid, y_valid),epochs=100, callbacks =[keras.callbacks.EarlyStopping(patience = 10)])
# Out:
# Epoch 1/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.9812 - accuracy: 0.6912 - val_loss: 0.3206 - val_accuracy: 0.9056
# Epoch 2/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4255 - accuracy: 0.8705 - val_loss: 0.2698 - val_accuracy: 0.9224
# Epoch 3/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3739 - accuracy: 0.8855 - val_loss: 0.2448 - val_accuracy: 0.9304
# Epoch 4/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3336 - accuracy: 0.8993 - val_loss: 0.2224 - val_accuracy: 0.9372
# Epoch 5/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3126 - accuracy: 0.9056 - val_loss: 0.2018 - val_accuracy: 0.9442
# Epoch 6/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2786 - accuracy: 0.9167 - val_loss: 0.1880 - val_accuracy: 0.9474
# Epoch 7/100
# ...

# %% [markdown]
# Dropout Monte Carlo

# %%
import numpy as np
y_probas = np.stack([model(X_test, trainining = True) for sample in range(100)])
